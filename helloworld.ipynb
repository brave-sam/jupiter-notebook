# %%
import pandas

# %%
raw_housing_data = pandas.read_csv('/content/drive/MyDrive/jupyter/1. Regression - Module - (Housing Prices).csv')

# %%
raw_housing_data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 18452  3375800220       15 March 2016    353000.0               3
# 18453  8898700820        14 July 2017    170500.0               2
# 18454  2725069156        14 July 2017    885250.0               4
# 18455  8043700300        14 June 2017   2700000.0               4
# 18456  2372800100   14 September 2017    245000.0               3
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
raw_housing_data.head(5)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...           7.0
# ...

# %%
raw_housing_data.tail(5)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 18452  3375800220       15 March 2016    353000.0               3
# 18453  8898700820        14 July 2017    170500.0               2
# 18454  2725069156        14 July 2017    885250.0               4
# 18455  8043700300        14 June 2017   2700000.0               4
# 18456  2372800100   14 September 2017    245000.0               3
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 18452             2.50               2550.0              6021.0           2.0
# 18453             1.00               1060.0              7700.0           1.0
# 18454             2.50               3670.0             49658.0           2.0
# 18455             3.25               4420.0              7850.0           2.0
# 18456             1.50               1550.0              9126.0           1.0
#
#       Waterfront View No of Times Visited  ... Overall Grade  \
# ...

# %%
raw_housing_data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  1.845700e+04  1.845500e+04    18457.000000     18455.000000
# mean   4.570511e+09  5.336770e+05        3.362410         2.062165
# std    2.860382e+09  3.655648e+05        0.934309         0.759834
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.124079e+09  3.150000e+05        3.000000         1.500000
# 50%    3.914000e+09  4.470000e+05        3.000000         2.000000
# 75%    7.287100e+09  6.360000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         18451.000000        1.844800e+04  18457.000000   18456.000000
# mean           2051.737304        1.577147e+04      1.433169       7.559222
# std             903.746352        4.237912e+04      0.509836       1.100609
# ...

# %%
raw_housing_data.describe(include='all')
# Out:
#                   ID Date House was Sold    Sale Price  No of Bedrooms  \
# count   1.845700e+04               18457  1.845500e+04    18457.000000
# unique           NaN                  13           NaN             NaN
# top              NaN       15 April 2016           NaN             NaN
# freq             NaN                1915           NaN             NaN
# mean    4.570511e+09                 NaN  5.336770e+05        3.362410
# std     2.860382e+09                 NaN  3.655648e+05        0.934309
# min     1.000102e+06                 NaN  7.500000e+04        0.000000
# 25%     2.124079e+09                 NaN  3.150000e+05        3.000000
# 50%     3.914000e+09                 NaN  4.470000e+05        3.000000
# 75%     7.287100e+09                 NaN  6.360000e+05        4.000000
# max     9.900000e+09                 NaN  7.700000e+06       33.000000
#
#         No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# ...

# %%
raw_housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18457 entries, 0 to 18456
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         18457 non-null  int64
#  1   Date House was Sold                        18457 non-null  object
#  2   Sale Price                                 18455 non-null  float64
#  3   No of Bedrooms                             18457 non-null  int64
#  4   No of Bathrooms                            18455 non-null  float64
#  5   Flat Area (in Sqft)                        18451 non-null  float64
#  6   Lot Area (in Sqft)                         18448 non-null  float64
#  7   No of Floors                               18457 non-null  float64
#  8   Waterfront View                            18457 non-null  object
#  9   No of Times Visited                        18457 non-null  object
# ...

# %%
raw_housing_data['Sale Price'].min()

# %%
raw_housing_data['Sale Price'].min()

# %%
raw_housing_data['Sale Price'].max()

# %%
raw_housing_data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                float64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                      float64
# Age of House (in Years)                      float64
# Renovated Year                               float64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
i='jo'
if (i=='late'):
  print('order')
else:
  print('cook')
# Out:
# cook

# %%
i = 98
if(i>80):
  print('Good')
elif(i<80):
   print('bad')
# Out:
# Good

# %%
for i in range(0,6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
fact = 1
for i in range(1,11):
  fact = fact*i
print(fact)
# Out:
# 3628800

# %%
def sam(a):
  sq= a*a
  return sq

sam(5)
# Out:
# 25

# %%
def factorial(value):
  fact  = 1
  for i in range(1,value+1):
    fact = fact*i
  return fact
n= 10
r=6
c=factorial(n)/(factorial(r)*factorial(n-r))
print("Number of combination ="+str(c))
# Out:
# Number of combination =210.0

# %%
s ="intern"
for i in range(len(s)):
  print(s)
  s='z'
# Out:
# intern
# z
# z
# z
# z
# z
